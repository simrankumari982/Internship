# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('C:/Users/Simran Kumari/Downloads/Micro-Credit-Project--3-/Micro Credit Project/Data file.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                2.0                0.0              1539  ...
# 1               20.0                0.0              5787  ...
# 2                3.0                0.0              1539  ...
# 3               41.0                0.0               947  ...
# 4                4.0                0.0              2309  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %%
df.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %%
df.shape
# Out:
# (209593, 36)

# %%
df.isna().sum().plot(kind="bar")
df.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# ...

# %%
#there are no null values in the data

# %%
len(pd.unique(df["msisdn"]))
# Out:
# 186243

# %%
df.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
cols=df.columns
cols
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %%
#mobile number wont affect the decision
df['pcircle'].value_counts()
# Out:
# UPW    209593
# Name: pcircle, dtype: int64

# %%
#other than pdate,pcircle and mobile number everything is in numerical datatype

# %%
df['label'].value_counts()
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %%
#the data is imbalanced

# %%
df.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
#the data is widely spread

# %%
for i in cols[2:-2]:
    sns.boxplot(df[i])
    plt.show()

# %%
#from the above we can see there are alot of outliers in the data

# %%
for i in cols[2:-2]:
    sns.distplot(df[i])
    plt.show()

# %%
#the data is highly skewed

# %%
for i in cols[2:-2]:
    sns.violinplot(df[i])
    plt.show()

# %%
for i in cols[2:-2]:
    sns.scatterplot(df['label'],df[i])
    plt.show()

# %%
df.corr()
# Out:
#                          label       aon  daily_decr30  daily_decr90  \
# label                 1.000000 -0.003785      0.168298      0.166150
# aon                  -0.003785  1.000000      0.001104      0.000374
# daily_decr30          0.168298  0.001104      1.000000      0.977704
# daily_decr90          0.166150  0.000374      0.977704      1.000000
# rental30              0.058085 -0.000960      0.442066      0.434685
# rental90              0.075521 -0.000790      0.458977      0.471730
# last_rech_date_ma     0.003728  0.001692      0.000487      0.000908
# last_rech_date_da     0.001711 -0.001693     -0.001636     -0.001886
# last_rech_amt_ma      0.131804  0.004256      0.275837      0.264131
# cnt_ma_rech30         0.237331 -0.003148      0.451385      0.426707
# fr_ma_rech30          0.001330 -0.001163     -0.000577     -0.000343
# sumamnt_ma_rech30     0.202828  0.000707      0.636536      0.603886
# medianamnt_ma_rech30  0.141490  0.004306      0.295356      0.282960
# ...

# %%
plt.figure(figsize=(30,30))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
g=sns.catplot(x="label",data=df,kind="count",palette="PRGn",alpha=1)
g.set(xlabel="Label",ylabel="Count")
plt.show()

# %%
#feature selection

# %%
Xsel=df.iloc[:,2:34]
Ysel=df.iloc[:,0]

# %%
df.skew()
# Out:
# label                   -2.270254
# aon                     10.392949
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental30                 4.521929
# rental90                 4.437681
# last_rech_date_ma       14.790974
# last_rech_date_da       14.814857
# last_rech_amt_ma         3.781149
# cnt_ma_rech30            3.283842
# fr_ma_rech30            14.772833
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# medianmarechprebal30    14.779875
# cnt_ma_rech90            3.425254
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        4.897950
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    44.880503
# cnt_da_rech30           17.818364
# fr_da_rech30            14.776430
# cnt_da_rech90           27.267278
# fr_da_rech90            28.988083
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# maxamnt_loans30         17.658052
# medianamnt_loans30       4.551043
# ...

# %%
from scipy.stats import zscore

# %%
df
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 1           1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 2           1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 3           1  55773I70781   241.0     21.228000     21.228000    159.42
# 4           1  03813I82730   947.0    150.619333    150.619333   1098.90
# ...       ...          ...     ...           ...           ...       ...
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %%
x=df.iloc[:,2:34]
y=df.iloc[:,0]

# %%
import scipy.stats as st
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor as viff
def calc_vif(x1):
    vif=pd.DataFrame()
    vif["variables"]=x1.columns
    vif['VIF Factor']=[viff(x1.values,i) for i in range(x1.shape[1])]
    return(vif)

# %%
calc_vif(x)
# Out:
#                variables  VIF Factor
# 0                    aon    1.011072
# 1           daily_decr30   38.953683
# 2           daily_decr90   41.888441
# 3               rental30   18.261312
# 4               rental90   18.833294
# 5      last_rech_date_ma    1.004762
# 6      last_rech_date_da    1.004785
# 7       last_rech_amt_ma    6.028751
# 8          cnt_ma_rech30   28.083715
# 9           fr_ma_rech30    1.004692
# 10     sumamnt_ma_rech30   20.031425
# 11  medianamnt_ma_rech30    8.961639
# 12  medianmarechprebal30    1.004856
# 13         cnt_ma_rech90   28.763293
# 14          fr_ma_rech90    1.439525
# 15     sumamnt_ma_rech90   23.277621
# 16  medianamnt_ma_rech90   10.068642
# 17  medianmarechprebal90    1.131273
# 18         cnt_da_rech30    1.003914
# 19          fr_da_rech30    1.004726
# 20         cnt_da_rech90    1.159568
# 21          fr_da_rech90    1.142600
# 22           cnt_loans30   34.175954
# 23          amnt_loans30   45.138368
# ...

# %%
#amnt_loans30 is very colinear
df.drop(['amnt_loans30'],inplace=True,axis=1)

# %%
calc_vif(df.iloc[:,2:33])
# Out:
#                variables  VIF Factor
# 0                    aon    1.010923
# 1           daily_decr30   38.550833
# 2           daily_decr90   41.791605
# 3               rental30   18.254773
# 4               rental90   18.832381
# 5      last_rech_date_ma    1.004688
# 6      last_rech_date_da    1.004732
# 7       last_rech_amt_ma    6.026410
# 8          cnt_ma_rech30   27.355522
# 9           fr_ma_rech30    1.004620
# 10     sumamnt_ma_rech30   20.026584
# 11  medianamnt_ma_rech30    8.938849
# 12  medianmarechprebal30    1.004803
# 13         cnt_ma_rech90   26.951728
# 14          fr_ma_rech90    1.433735
# 15     sumamnt_ma_rech90   23.204233
# 16  medianamnt_ma_rech90   10.052339
# 17  medianmarechprebal90    1.131268
# 18         cnt_da_rech30    1.003787
# 19          fr_da_rech30    1.004547
# 20         cnt_da_rech90    1.159556
# 21          fr_da_rech90    1.142579
# 22           cnt_loans30   15.300463
# 23       maxamnt_loans30    1.004126
# ...

# %%
#daily_decr90 as well is very colinear

# %%
#amnt_loans30 is very colinear
df.drop(['daily_decr90'],inplace=True,axis=1)

# %%
calc_vif(df.iloc[:,2:32])
# Out:
#                variables  VIF Factor
# 0                    aon    1.010917
# 1           daily_decr30    4.040526
# 2               rental30   17.204000
# 3               rental90   17.671018
# 4      last_rech_date_ma    1.004676
# 5      last_rech_date_da    1.004732
# 6       last_rech_amt_ma    6.026299
# 7          cnt_ma_rech30   27.291547
# 8           fr_ma_rech30    1.004614
# 9      sumamnt_ma_rech30   18.572404
# 10  medianamnt_ma_rech30    8.919042
# 11  medianmarechprebal30    1.004794
# 12         cnt_ma_rech90   26.885931
# 13          fr_ma_rech90    1.433340
# 14     sumamnt_ma_rech90   20.732332
# 15  medianamnt_ma_rech90   10.030433
# 16  medianmarechprebal90    1.131063
# 17         cnt_da_rech30    1.003784
# 18          fr_da_rech30    1.004547
# 19         cnt_da_rech90    1.159488
# 20          fr_da_rech90    1.142571
# 21           cnt_loans30   15.024212
# 22       maxamnt_loans30    1.004121
# 23    medianamnt_loans30    6.377639
# ...

# %%
#cnt_ma_rech90 is very colinear
df.drop(['cnt_ma_rech90'],inplace=True,axis=1)

# %%
df.shape
# Out:
# (209593, 33)

# %%
df
# Out:
#         label       msisdn     aon  daily_decr30  rental30  rental90  \
# 0           0  21408I70789   272.0   3055.050000    220.13    260.13
# 1           1  76462I70374   712.0  12122.000000   3691.26   3691.26
# 2           1  17943I70372   535.0   1398.000000    900.13    900.13
# 3           1  55773I70781   241.0     21.228000    159.42    159.42
# 4           1  03813I82730   947.0    150.619333   1098.90   1098.90
# ...       ...          ...     ...           ...       ...       ...
# 209588      1  22758I85348   404.0    151.872333   1089.19   1089.19
# 209589      1  95583I84455  1075.0     36.936000   1728.36   1728.36
# 209590      1  28556I85350  1013.0  11843.111667   5861.83   8893.20
# 209591      1  59712I82733  1732.0  12488.228333    411.83    984.58
# 209592      1  65061I85339  1581.0   4489.362000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
df.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
#        'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
#        'medianamnt_ma_rech30', 'medianmarechprebal30', 'fr_ma_rech90',
#        'sumamnt_ma_rech90', 'medianamnt_ma_rech90', 'medianmarechprebal90',
#        'cnt_da_rech30', 'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90',
#        'cnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
df.drop(['msisdn','pcircle', 'pdate'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (209593, 30)

# %%
from scipy.stats import zscore
z=zscore(df)

# %%
for i in [3,3.2,3.4,3.6,3.8,4.0,4.2,4.4,4.6,4.8]:
    df1=df.copy()
    df_new=df[(z<i).all(axis=1)]
    loss=((df1.shape[0]-df_new.shape[0])*100)/df1.shape[0]
    print ("At i",i," loss % is",loss)
# Out:
# At i 3  loss % is 21.717805461060244
# At i 3.2  loss % is 20.27644052997953
# At i 3.4  loss % is 18.755874480540857
# At i 3.6  loss % is 17.630359792550323
# At i 3.8  loss % is 16.60694775111764
# At i 4.0  loss % is 15.299175067869633
# At i 4.2  loss % is 14.470903131306866
# At i 4.4  loss % is 13.377832274932846
# At i 4.6  loss % is 12.766647741098224
# At i 4.8  loss % is 9.622935880492191

# %%
df=df[(z<4.8).all(axis=1)]

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
x.shape,y.shape
# Out:
# ((189424, 29), (189424,))

# %%
from imblearn.under_sampling import NearMiss
nm=NearMiss()
x,y=nm.fit_resample(x,y)

# %%
x.shape,y.shape
# Out:
# ((48178, 29), (48178,))

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
for i in df.columns:
    if np.abs(df[i].skew())>0.5:
        df[i]=pt.fit_transform(df[i].values.reshape(-1,1))
    elif np.abs(df[i].skew())<-0.5:
        df[i]=pt.fit_transform(df[i].values.reshape(-1,1))

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
x=mms.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lg=LogisticRegression()
x_train=x
y_train=y
x_test=x
y_test=y
acc=0
r_state=0
for i in (0,1000):
    tr_x,t_x,tr_y,t_y=train_test_split(x,y,random_state=i,test_size=0.20)
    lg.fit(tr_x,tr_y)
    pred=lg.predict(t_x)
    if accuracy_score(t_y,pred)>acc:
        acc=accuracy_score(t_y,pred)
        x_train=tr_x
        x_test=t_x
        y_train=tr_y
        y_test=t_y
        r_state=i
print("At random state",r_state,"accuracy score is maximum i.e.,",acc)
# Out:
# At random state 0 accuracy score is maximum i.e., 0.7131589871315899

# %%
def fun(f):
    f.fit(x_train,y_train)
    pred=f.predict(x_test)
    print("Accuracy score",accuracy_score(y_test,pred))
    print("Confusion Matrix\n",confusion_matrix(y_test,pred))
    print("Classification report\n",classification_report(y_test,pred))

# %%
fun(lg)
# Out:
# Accuracy score 0.7131589871315899
# Confusion Matrix
#  [[2776 2070]
#  [ 694 4096]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.80      0.57      0.67      4846
#            1       0.66      0.86      0.75      4790
#
#     accuracy                           0.71      9636
#    macro avg       0.73      0.71      0.71      9636
# weighted avg       0.73      0.71      0.71      9636

# %%
from sklearn.model_selection import cross_val_score,KFold
def cvs(m):
    cv1=KFold(n_splits=5,shuffle=True)
    score=cross_val_score(m,x,y,cv=cv1,scoring='accuracy')
    print("Cross val score",score)
    print(score.mean())

# %%
from sklearn.model_selection import GridSearchCV
def hypertuning(params,model):
    gd=GridSearchCV(model,params,cv=5,scoring='accuracy')
    gd.fit(x,y)
    print(gd.best_params_)

# %%
cvs(lg)
# Out:
# Cross val score [0.70205479 0.71855542 0.70163968 0.70451479 0.71862999]
# 0.709078936172367

# %%
acc=[71.31]
CVS=[70.91]
model=['Lgistic Regression']

# %%
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
svc=SVC()
dtc=DecisionTreeClassifier()
knn=KNeighborsClassifier()
gb=GaussianNB()

# %%
fun(svc)
cvs(svc)
# Out:
# Accuracy score 0.7242631797426318
# Confusion Matrix
#  [[2747 2099]
#  [ 558 4232]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.83      0.57      0.67      4846
#            1       0.67      0.88      0.76      4790
#
#     accuracy                           0.72      9636
#    macro avg       0.75      0.73      0.72      9636
# weighted avg       0.75      0.72      0.72      9636
#
# Cross val score [0.72281029 0.72488584 0.72114985 0.72537623 0.71686559]
# 0.7222175641724091

# %%
fun(dtc)
cvs(dtc)
# Out:
# Accuracy score 0.7992943129929432
# Confusion Matrix
#  [[3889  957]
#  [ 977 3813]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80      4846
#            1       0.80      0.80      0.80      4790
#
#     accuracy                           0.80      9636
#    macro avg       0.80      0.80      0.80      9636
# weighted avg       0.80      0.80      0.80      9636
#
# Cross val score [0.80199253 0.79586966 0.79846409 0.80072652 0.80145304]
# 0.7997011660347387

# %%
fun(knn)
cvs(knn)
# Out:
# Accuracy score 0.7135740971357409
# Confusion Matrix
#  [[3137 1709]
#  [1051 3739]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.75      0.65      0.69      4846
#            1       0.69      0.78      0.73      4790
#
#     accuracy                           0.71      9636
#    macro avg       0.72      0.71      0.71      9636
# weighted avg       0.72      0.71      0.71      9636
#
# Cross val score [0.6983188  0.7107721  0.70630967 0.70430721 0.70659056]
# 0.7052596699412319

# %%
acc.append(71.35)
CVS.append(70.53)
model.append('K Neighbors')

# %%
acc.append(79.92)
CVS.append(79.97)
model.append('Decision Tree')

# %%
fun(gb)
cvs(gb)
# Out:
# Accuracy score 0.635118306351183
# Confusion Matrix
#  [[1603 3243]
#  [ 273 4517]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.85      0.33      0.48      4846
#            1       0.58      0.94      0.72      4790
#
#     accuracy                           0.64      9636
#    macro avg       0.72      0.64      0.60      9636
# weighted avg       0.72      0.64      0.60      9636
#
# Cross val score [0.6420714  0.63875052 0.63895807 0.62906072 0.640685  ]
# 0.6379051420863167

# %%
CVS.append(63.51)
acc.append(63.79)
model.append('Gaussian NB')

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()

# %%
fun(rf)
cvs(rf)
# Out:
# Accuracy score 0.8569946035699461
# Confusion Matrix
#  [[4005  841]
#  [ 537 4253]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85      4846
#            1       0.83      0.89      0.86      4790
#
#     accuracy                           0.86      9636
#    macro avg       0.86      0.86      0.86      9636
# weighted avg       0.86      0.86      0.86      9636
#
# Cross val score [0.85253217 0.85689083 0.8528435  0.85480021 0.85646082]
# 0.8547055056253114

# %%
CVS.append(85.47)
acc.append(85.69)
model.append('random Forest')

# %%
from sklearn.tree import ExtraTreeClassifier
etc=ExtraTreeClassifier()

# %%
fun(etc)
cvs(etc)
# Out:
# Accuracy score 0.7460564549605645
# Confusion Matrix
#  [[3598 1248]
#  [1199 3591]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.75      0.74      0.75      4846
#            1       0.74      0.75      0.75      4790
#
#     accuracy                           0.75      9636
#    macro avg       0.75      0.75      0.75      9636
# weighted avg       0.75      0.75      0.75      9636
#
# Cross val score [0.74782067 0.74636779 0.74512246 0.74270887 0.73990659]
# 0.7443852763691252

# %%
CVS.append(74.43)
acc.append(74.60)
model.append('Extra Tree')

# %%
from sklearn.ensemble import AdaBoostClassifier
ada=AdaBoostClassifier()

# %%
fun(ada)
cvs(ada)
# Out:
# Accuracy score 0.825653798256538
# Confusion Matrix
#  [[3686 1160]
#  [ 520 4270]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.88      0.76      0.81      4846
#            1       0.79      0.89      0.84      4790
#
#     accuracy                           0.83      9636
#    macro avg       0.83      0.83      0.83      9636
# weighted avg       0.83      0.83      0.82      9636
#
# Cross val score [0.83115401 0.83022001 0.82648402 0.8265698  0.82573949]
# 0.8280334642857834

# %%
CVS.append(82.80)
acc.append(82.56)
model.append('Ada Boost')

# %%
from sklearn.ensemble import GradientBoostingClassifier
Gd=GradientBoostingClassifier()
fun(Gd)
cvs(Gd)
# Out:
# Accuracy score 0.8370693233706933
# Confusion Matrix
#  [[3739 1107]
#  [ 463 4327]]
# Classification report
#                precision    recall  f1-score   support
#
#            0       0.89      0.77      0.83      4846
#            1       0.80      0.90      0.85      4790
#
#     accuracy                           0.84      9636
#    macro avg       0.84      0.84      0.84      9636
# weighted avg       0.84      0.84      0.84      9636
#
# Cross val score [0.84537152 0.83613533 0.83509755 0.84525169 0.84670472]
# 0.8417121618183672

# %%
CVS.append(84.17)
acc.append(83.70)
model.append('GD Boost')

# %%
res=pd.DataFrame()
res['Models']=model
res['CVS']=CVS
res['Accuracy']=acc
diff=[]
for i in range(0,len(acc)):
    diff.append(acc[i]-CVS[i])
res['diff']=diff
res
# Out:
#                Models    CVS  Accuracy  diff
# 0  Lgistic Regression  70.91     71.31  0.40
# 1         K Neighbors  70.53     71.35  0.82
# 2       Decision Tree  79.97     79.92 -0.05
# 3         Gaussian NB  63.51     63.79  0.28
# 4       random Forest  85.47     85.69  0.22
# 5          Extra Tree  74.43     74.60  0.17
# 6           Ada Boost  82.80     82.56 -0.24
# 7            GD Boost  84.17     83.70 -0.47

# %%
#from above we can see random forest is the best

# %%
import pickle
filename='Loan Payable Pred.pkl'
pickle.dump(knn,open(filename,'wb'))

# %%
predict=rf.predict(x_test)

# %%
output=pd.DataFrame()
output['Actual']=y_test
output['Predicted']=predict
output
# Out:
#        Actual  Predicted
# 43034       1          0
# 9069        0          0
# 38119       1          1
# 786         0          1
# 26054       1          1
# ...       ...        ...
# 33264       1          1
# 26495       1          1
# 26929       1          1
# 30825       1          1
# 5710        0          1
#
# [9636 rows x 2 columns]

# %%
output.to_csv('Loan_Status_Project.csv')

# %%
from sklearn.metrics import roc_curve,roc_auc_score

# %%
y_pred_prob=knn.predict_proba(x_test)[:,1]

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)

# %%
plt.plot(fpr,tpr)
plt.show()
