# %%
str1=input("Enter the string")
all_freq={}
for i in str1:
    if i in all_freq:
        all_freq[1]=+1
    else:
        all_freq[i]=1
print(all_freq)
# Out:
# Enter the string tyghjkjhhhh
# {'t': 1, 'y': 1, 'g': 1, 'h': 1, 'j': 1, 'k': 1, 1: 1}

# %%
s
