# %%
import math
p=int(input("Enter the height"))
b=int(input("Enter the base"))
h=math.sqrt(math.pow(p,2)+math.pow(b,2))
print("The third side is ",h)
# Out:
# Enter the height 5
# Enter the base 12
# The third side is  13.0
